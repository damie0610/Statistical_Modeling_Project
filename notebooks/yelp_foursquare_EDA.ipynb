# %%
# imports
# Importing necessary libraries
import pandas as pd
import requests
import json
import os

# %%
# Accessing environmental variables
yelp_key = os.environ.get('yelp_api')
yelp_key2 = os.environ.get('yelp_api2')
FOURSQUARE_KEY = os.environ.get('FOURSQUARE_API_KEY')

# %%
# Import ph_bikes to use latitude-longitude pairs

# read in saved csv of philly bike stations.
ph_bikes = pd.read_csv("C:/Users/HP/Music/LHLDataCourse/Python/project_data/ph_bikes.csv")
ph_bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233 entries, 0 to 232
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           233 non-null    int64
#  1   name         233 non-null    object
#  2   empty_slots  233 non-null    int64
#  3   free_bikes   233 non-null    int64
#  4   latitude     233 non-null    float64
#  5   longitude    233 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 11.1+ KB

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %% [markdown]
# ### POIs Selected - Colleges/Universities & Fitness-Related Businesses.
# #### *I aim to observe the impact, if any, of the proximity to the POIs on bike usage and so, when making the calls, I sort by distance and loop through the data to access the closest business for ech latitude-longitude pair.*
#
# - For the College/Uni POI, I remove radius limits since universities are not as commonly found as fitness centers but I maintain the radius of 1000 for fitness centers.

# %% [markdown]
# ### Fitness POI

# %%
# Function created to make a call to foursquare.

def get_fsq(latitude, longitude, radius, api_key, categories):

    url = "https://api.foursquare.com/v3/places/search"

    params = {
        "ll": '{},{}'.format(latitude, longitude),
        "radius": radius,
        "categories": categories,
        "sort": sort,
        # "limit": 50
    }

    headers = {
        "Accept": "application/json",
        "Authorization": FOURSQUARE_KEY
    }

    response = requests.request("GET", url, params=params, headers=headers)
    return response.json()

# %%
# assign values for fitness POI
latitude = ph_bikes['latitude']
longitude = ph_bikes['longitude']
radius = 1000
sort = "distance"
categories = 18021  # sports and recreation > gym & studio

# %%
# Testing the function
from pprint import pprint

# testing
res = get_fsq(latitude=51.51, longitude=-0.1337, radius=1000, api_key=FOURSQUARE_KEY, categories=18000)
pprint(res)
# Out:
# {'context': {'geo_bounds': {'circle': {'center': {'latitude': 51.51,
#                                                   'longitude': -0.1337},
#                                        'radius': 1000}}},
#  'results': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#                                        'suffix': '.png'},
#                               'id': 10039,
#                               'name': 'Music Venue'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#                                        'suffix': '.png'},
#                               'id': 11035,
#                               'name': 'Entertainment Agency'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#                                        'suffix': '.png'},
#                               'id': 18000,
#                               'name': 'Sports and Recreation'}],
#               'chains': [],
#               'distance': 149,
#               'fsq_id': '525fbc037b3242b1a605ee10',
#               'geocodes': {'main': {'latitude': 51.509116,
#                                     'longitude': -0.132078},
#                            'roof': {'latitude': 51.509116,
#                                     'longitude': -0.132078}},
#               'link': '/v3/places/525fbc037b3242b1a605ee10',
#               'location': {'address': '23 Haymarket',
#                            'admin_region': 'England',
#                            'country': 'GB',
#                            'formatted_address': '23 Haymarket, London, Greater '
#                                                 'London, SW1Y 4DG',
#                            'locality': 'London',
#                            'post_town': 'London',
#                            'postcode': 'SW1Y 4DG',
#                            'region': 'Greater London'},
#               'name': 'Global Artists',
#               'related_places': {},
#               'timezone': 'Europe/London'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#                                        'suffix': '.png'},
#                               'id': 18021,
#                               'name': 'Gym and Studio'}],
#               'chains': [],
#               'distance': 167,
#               'fsq_id': '5707d85a498e119ec0c721e5',
#               'geocodes': {'main': {'latitude': 51.50852,
#                                     'longitude': -0.133264},
#                            'roof': {'latitude': 51.50852,
#                                     'longitude': -0.133264}},
#               'link': '/v3/places/5707d85a498e119ec0c721e5',
#               'location': {'address': 'Rex House',
#                            'admin_region': 'England',
#                            'country': 'GB',
#                            'cross_street': '',
#                            'formatted_address': 'Rex House, London, Greater '
#                                                 'London, SW1Y 4PE',
#                            'locality': 'London',
#                            'post_town': 'London',
#                            'postcode': 'SW1Y 4PE',
#                            'region': 'Greater London'},
#               'name': 'Pure Gym - London Piccadilly',
#               'related_places': {},
#               'timezone': 'Europe/London'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#                                        'suffix': '.png'},
#                               'id': 18021,
#                               'name': 'Gym and Studio'}],
#               'chains': [],
#               'distance': 177,
#               'fsq_id': '5e5007076f7fe50008cb431e',
#               'geocodes': {'drop_off': {'latitude': 51.508612,
#                                         'longitude': -0.134999},
#                            'main': {'latitude': 51.508715,
#                                     'longitude': -0.134885},
#                            'roof': {'latitude': 51.508715,
#                                     'longitude': -0.134885}},
#               'link': '/v3/places/5e5007076f7fe50008cb431e',
#               'location': {'address': 'Babmaes St',
#                            'admin_region': 'England',
#                            'country': 'GB',
#                            'cross_street': 'Sw1y 6hd',
#                            'formatted_address': 'Babmaes St (Sw1y 6hd), '
#                                                 'London, Greater London, SW1Y '
#                                                 '6HD',
#                            'locality': 'London',
#                            'post_town': 'London',
#                            'postcode': 'SW1Y 6HD',
#                            'region': 'Greater London'},
#               'name': '24N Mayfair',
#               'related_places': {},
#               'timezone': 'Europe/London'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#                                        'suffix': '.png'},
#                               'id': 18000,
#                               'name': 'Sports and Recreation'}],
#               'chains': [],
#               'distance': 203,
#               'fsq_id': 'b296ecf47987449bf5325a54',
#               'geocodes': {'main': {'latitude': 51.509399,
#                                     'longitude': -0.136484},
#                            'roof': {'latitude': 51.509399,
#                                     'longitude': -0.136484}},
#               'link': '/v3/places/b296ecf47987449bf5325a54',
#               'location': {'admin_region': 'England',
#                            'country': 'GB',
#                            'formatted_address': 'Piccadilly',
#                            'locality': 'Piccadilly',
#                            'post_town': 'London'},
#               'name': 'The Piccadilly Health Club and Spa',
#               'related_places': {}},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#                                        'suffix': '.png'},
#                               'id': 18028,
#                               'name': 'Yoga Studio'}],
#               'chains': [],
#               'distance': 206,
#               'fsq_id': '4ad3061af964a520f9e220e3',
#               'geocodes': {'main': {'latitude': 51.511214,
#                                     'longitude': -0.135839},
#                            'roof': {'latitude': 51.511214,
#                                     'longitude': -0.135839}},
#               'link': '/v3/places/4ad3061af964a520f9e220e3',
#               'location': {'address': '67 Brewer St',
#                            'admin_region': 'England',
#                            'country': 'GB',
#                            'formatted_address': '67 Brewer St, London, Greater '
#                                                 'London, W1F 9US',
#                            'locality': 'London',
#                            'post_town': 'London',
#                            'postcode': 'W1F 9US',
#                            'region': 'Greater London'},
#               'name': 'The Third Space',
#               'related_places': {'children': [{'fsq_id': '5a70502bad178913ef7ffea3',
#                                                'name': 'Suki Su Permanent '
#                                                        'Makeup'},
#                                               {'fsq_id': '55b294c8498eca56abec5efb',
#                                                'name': 'Natural Fitness '
#                                                        'Food'}]},
#               'timezone': 'Europe/London'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#                                        'suffix': '.png'},
#                               'id': 18021,
#                               'name': 'Gym and Studio'}],
#               'chains': [],
#               'distance': 264,
#               'fsq_id': '5881e9efcc5b6a08df5a8768',
#               'geocodes': {'drop_off': {'latitude': 51.510007,
#                                         'longitude': -0.129706},
#                            'main': {'latitude': 51.509875,
#                                     'longitude': -0.129693},
#                            'roof': {'latitude': 51.509875,
#                                     'longitude': -0.129693}},
#               'link': '/v3/places/5881e9efcc5b6a08df5a8768',
#               'location': {'address': '31-36 Leicester Sq',
#                            'admin_region': 'England',
#                            'country': 'GB',
#                            'cross_street': '',
#                            'formatted_address': '31-36 Leicester Sq, London, '
#                                                 'Greater London, WC2H 7LH',
#                            'locality': 'London',
#                            'post_town': 'London',
#                            'postcode': 'WC2H 7LH',
#                            'region': 'Greater London'},
#               'name': 'Radisson Blu Gym',
#               'related_places': {'parent': {'fsq_id': '4ac518b5f964a5209fa020e3',
#                                             'name': 'Radisson Blu Edwardian '
#                                                     'Hampshire Hotel, London'}},
#               'timezone': 'Europe/London'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#                                        'suffix': '.png'},
#                               'id': 12097,
#                               'name': 'Social Club'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#                                        'suffix': '.png'},
#                               'id': 18021,
#                               'name': 'Gym and Studio'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/travelagency_',
#                                        'suffix': '.png'},
#                               'id': 19055,
#                               'name': 'Travel Agency'}],
#               'chains': [],
#               'distance': 352,
#               'fsq_id': 'b8eda061253e46b0ac41893e',
#               'geocodes': {'drop_off': {'latitude': 51.512694,
#                                         'longitude': -0.131796},
#                            'main': {'latitude': 51.512874,
#                                     'longitude': -0.131534},
#                            'roof': {'latitude': 51.512874,
#                                     'longitude': -0.131534}},
#               'link': '/v3/places/b8eda061253e46b0ac41893e',
#               'location': {'address': '47 Dean St',
#                            'admin_region': 'England',
#                            'country': 'GB',
#                            'formatted_address': '47 Dean St, London, W1D 5BE',
#                            'locality': 'London',
#                            'post_town': 'London',
#                            'postcode': 'W1D 5BE'},
#               'name': 'Thryve',
#               'related_places': {}},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#                                        'suffix': '.png'},
#                               'id': 18021,
#                               'name': 'Gym and Studio'}],
#               'chains': [],
#               'distance': 395,
#               'fsq_id': '5a15521958002c7dfcb6b3b6',
#               'geocodes': {'main': {'latitude': 51.51247,
#                                     'longitude': -0.137915},
#                            'roof': {'latitude': 51.51247,
#                                     'longitude': -0.137915}},
#               'link': '/v3/places/5a15521958002c7dfcb6b3b6',
#               'location': {'admin_region': 'England',
#                            'country': 'GB',
#                            'cross_street': '',
#                            'formatted_address': 'London, Greater London, W1F '
#                                                 '9QG',
#                            'locality': 'London',
#                            'post_town': 'London',
#                            'postcode': 'W1F 9QG',
#                            'region': 'Greater London'},
#               'name': 'Fitness',
#               'related_places': {'parent': {'fsq_id': '4c46e604972c0f4784f82121',
#                                             'name': 'Sweaty Betty'}},
#               'timezone': 'Europe/London'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#                                        'suffix': '.png'},
#                               'id': 18021,
#                               'name': 'Gym and Studio'}],
#               'chains': [],
#               'distance': 427,
#               'fsq_id': '4c37134b18e72d7ff1cd15f5',
#               'geocodes': {'main': {'latitude': 51.513443,
#                                     'longitude': -0.136774},
#                            'roof': {'latitude': 51.513443,
#                                     'longitude': -0.136774}},
#               'link': '/v3/places/4c37134b18e72d7ff1cd15f5',
#               'location': {'address': 'Marshall St',
#                            'admin_region': 'England',
#                            'country': 'GB',
#                            'cross_street': '',
#                            'formatted_address': 'Marshall St, Greater London',
#                            'locality': 'Greater London',
#                            'region': 'Greater London'},
#               'name': 'Nuffield Health Soho',
#               'related_places': {},
#               'timezone': 'Europe/London'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#                                        'suffix': '.png'},
#                               'id': 12097,
#                               'name': 'Social Club'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#                                        'suffix': '.png'},
#                               'id': 18065,
#                               'name': 'Sports Club'}],
#               'chains': [],
#               'distance': 443,
#               'fsq_id': '559e2de1498e3287c87cbae1',
#               'geocodes': {'main': {'latitude': 51.513942,
#                                     'longitude': -0.13299},
#                            'roof': {'latitude': 51.513942,
#                                     'longitude': -0.13299}},
#               'link': '/v3/places/559e2de1498e3287c87cbae1',
#               'location': {'address': '76 Dean St',
#                            'admin_region': 'England',
#                            'country': 'GB',
#                            'cross_street': '',
#                            'formatted_address': '76 Dean St, London, Greater '
#                                                 'London, W1D 3SQ',
#                            'locality': 'London',
#                            'post_town': 'London',
#                            'postcode': 'W1D 3SQ',
#                            'region': 'Greater London'},
#               'name': 'Soho House 76 Dean Street',
#               'related_places': {},
#               'timezone': 'Europe/London'}]}

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
# getting each fitness center's distance from each station

# list to store each location's data
fitness_loc = []

# iterating through each lat-lng pair
for index, row in ph_bikes.iterrows():
    lat = row['latitude']
    lng = row['longitude']

    # call and append
    location = get_fsq(latitude=lat, longitude=lng, radius=1000, api_key=FOURSQUARE_KEY, categories=categories)

    # nested loop to iterate through centers for each location
    if 'results' in location and len(location['results']) > 0:
        first_distance = location['results'][0]['distance']
        fitness_loc.append(first_distance)
    else:
        # Handle cases where no centers are returned
        fitness_loc.append('NA')

# %%
len(fitness_loc)
# Out:
# 233

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
# Convert the data into a DataFrame and assign ID to aid when merging

fsq_fit = pd.DataFrame(fitness_loc)
fsq_fit = fsq_fit.rename_axis("ID").reset_index()

# %%
# Renaming the columns

fsq_fit.columns = ["ID", "fsq_center_dist"]
fsq_fit.head()
# Out:
#    ID fsq_center_dist
# 0   0             204
# 1   1             431
# 2   2              79
# 3   3             142
# 4   4             729

# %%
csv_file_path = 'fsq_fit.csv'

# Save the DataFrame to a CSV file
fsq_fit.to_csv(csv_file_path, index=False)

# %% [markdown]
# ###
# ### College POI

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
# assign values for collegeuniv POI
latitude = ph_bikes['latitude']
longitude = ph_bikes['longitude']
radius = None
sort = "distance"
categories = 12013 # college and university

# %%
# college testing
col = get_fsq(latitude=39.97195, longitude=-75.13445, radius=None, api_key=FOURSQUARE_KEY, categories=12013)
pprint(col)
# Out:
# {'context': {'geo_bounds': {'circle': {'center': {'latitude': 39.97195,
#                                                   'longitude': -75.13445},
#                                        'radius': 22000}}},
#  'results': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#                                        'suffix': '.png'},
#                               'id': 12014,
#                               'name': 'College Academic Building'}],
#               'chains': [],
#               'distance': 1867,
#               'fsq_id': '4b27a49af964a520168824e3',
#               'geocodes': {'main': {'latitude': 39.981465,
#                                     'longitude': -75.152612},
#                            'roof': {'latitude': 39.981465,
#                                     'longitude': -75.152612}},
#               'link': '/v3/places/4b27a49af964a520168824e3',
#               'location': {'address': '1115 W Berks St',
#                            'census_block': '421010377001016',
#                            'country': 'US',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1115 W Berks St, '
#                                                 'Philadelphia, PA 19122',
#                            'locality': 'Philadelphia',
#                            'postcode': '19122',
#                            'region': 'PA'},
#               'name': 'Gladfelter Hall',
#               'related_places': {'children': [],
#                                  'parent': {'fsq_id': '415c9e00f964a520511d1fe3',
#                                             'name': 'Temple University'}},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#                                        'suffix': '.png'},
#                               'id': 12027,
#                               'name': 'College Gym'}],
#               'chains': [],
#               'distance': 1928,
#               'fsq_id': '4c5da4697735c9b63fa48f72',
#               'geocodes': {'drop_off': {'latitude': 39.983868,
#                                         'longitude': -75.150226},
#                            'main': {'latitude': 39.984069,
#                                     'longitude': -75.150239},
#                            'roof': {'latitude': 39.984069,
#                                     'longitude': -75.150239}},
#               'link': '/v3/places/4c5da4697735c9b63fa48f72',
#               'location': {'address': '1051-1077 Diamond St',
#                            'census_block': '421010377003000',
#                            'country': 'US',
#                            'cross_street': '',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1051-1077 Diamond St, '
#                                                 'Philadelphia, PA 19122',
#                            'locality': 'Philadelphia',
#                            'postcode': '19122',
#                            'region': 'PA'},
#               'name': 'Chodoff Field',
#               'related_places': {},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/lab_',
#                                        'suffix': '.png'},
#                               'id': 12030,
#                               'name': 'College Lab'}],
#               'chains': [],
#               'distance': 1933,
#               'fsq_id': '53282278498e46e4f376c24e',
#               'geocodes': {'main': {'latitude': 39.981656,
#                                     'longitude': -75.153226},
#                            'roof': {'latitude': 39.981656,
#                                     'longitude': -75.153226}},
#               'link': '/v3/places/53282278498e46e4f376c24e',
#               'location': {'census_block': '421010377001016',
#                            'country': 'US',
#                            'cross_street': '',
#                            'dma': 'Philadelphia',
#                            'formatted_address': 'Philadelphia, PA 19122',
#                            'locality': 'Philadelphia',
#                            'postcode': '19122',
#                            'region': 'PA'},
#               'name': 'Science Education & Research Center',
#               'related_places': {'parent': {'fsq_id': '415c9e00f964a520511d1fe3',
#                                             'name': 'Temple University'}},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/studentcenter_',
#                                        'suffix': '.png'},
#                               'id': 12047,
#                               'name': 'Student Center'}],
#               'chains': [],
#               'distance': 1967,
#               'fsq_id': '4adfa098f964a520497c21e3',
#               'geocodes': {'main': {'latitude': 39.979451,
#                                     'longitude': -75.154979},
#                            'roof': {'latitude': 39.979451,
#                                     'longitude': -75.154979}},
#               'link': '/v3/places/4adfa098f964a520497c21e3',
#               'location': {'address': '1755 N 13th St',
#                            'census_block': '421010146002000',
#                            'country': 'US',
#                            'cross_street': 'at Montgomery Ave',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1755 N 13th St (at Montgomery '
#                                                 'Ave), Philadelphia, PA 19122',
#                            'locality': 'Philadelphia',
#                            'postcode': '19122',
#                            'region': 'PA'},
#               'name': 'Howard Gittis Student Center',
#               'related_places': {'children': [{'fsq_id': '59a40e0d4c954c5afe293101',
#                                                'name': 'Burgerfi'},
#                                               {'fsq_id': '4e6280c41f6ef7d07abddd02',
#                                                'name': 'The Reel'},
#                                               {'fsq_id': '5d63eb844d67cb0008ded9e6',
#                                                'name': 'Chick-Fil-A'},
#                                               {'fsq_id': '59a40ddd4c954c5afe28d44b',
#                                                'name': 'Twisted Taco'},
#                                               {'fsq_id': '614364fcd00d5f42ee166bd1',
#                                                'name': 'Pita & Co.'},
#                                               {'fsq_id': '59a483ff8134884bd023e55e',
#                                                'name': 'Saladworks'}],
#                                  'parent': {'fsq_id': '415c9e00f964a520511d1fe3',
#                                             'name': 'Temple University'}},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/academicbuilding_',
#                                        'suffix': '.png'},
#                               'id': 12014,
#                               'name': 'College Academic Building'}],
#               'chains': [],
#               'distance': 1972,
#               'fsq_id': '4b7d37bdf964a52044b32fe3',
#               'geocodes': {'drop_off': {'latitude': 39.982557,
#                                         'longitude': -75.153196},
#                            'main': {'latitude': 39.98252,
#                                     'longitude': -75.153023},
#                            'roof': {'latitude': 39.98252,
#                                     'longitude': -75.153023}},
#               'link': '/v3/places/4b7d37bdf964a52044b32fe3',
#               'location': {'address': '1947 N 12th St',
#                            'census_block': '421010377001016',
#                            'country': 'US',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1947 N 12th St, Philadelphia, '
#                                                 'PA 19122',
#                            'locality': 'Philadelphia',
#                            'postcode': '19122',
#                            'region': 'PA'},
#               'name': 'Temple University College of Engineering',
#               'related_places': {'parent': {'fsq_id': '415c9e00f964a520511d1fe3',
#                                             'name': 'Temple University'}},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#                                        'suffix': '.png'},
#                               'id': 12013,
#                               'name': 'College and University'}],
#               'chains': [],
#               'distance': 2047,
#               'fsq_id': '415c9e00f964a520511d1fe3',
#               'geocodes': {'main': {'latitude': 39.98079,
#                                     'longitude': -75.15554},
#                            'roof': {'latitude': 39.980279,
#                                     'longitude': -75.15714}},
#               'link': '/v3/places/415c9e00f964a520511d1fe3',
#               'location': {'address': '1801 N Broad St',
#                            'address_extended': 'Ste 4',
#                            'census_block': '421010377001014',
#                            'country': 'US',
#                            'cross_street': 'at Montgomery Ave',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1801 N Broad St (at '
#                                                 'Montgomery Ave), '
#                                                 'Philadelphia, PA 19122',
#                            'locality': 'Philadelphia',
#                            'postcode': '19122',
#                            'region': 'PA'},
#               'name': 'Temple University',
#               'related_places': {'children': [{'fsq_id': '4c4aee7242b4d13a94ccf07d',
#                                                'name': 'Sydenham Commons'},
#                                               {'fsq_id': '4b969974f964a520a9d734e3',
#                                                'name': 'Weiss Hall'},
#                                               {'fsq_id': '4b7d37bdf964a52044b32fe3',
#                                                'name': 'Temple University '
#                                                        'College of '
#                                                        'Engineering'},
#                                               {'fsq_id': '4b7cb97bf964a52012a32fe3',
#                                                'name': 'Alpha Tau Omega '
#                                                        'Fraternity at Temple'},
#                                               {'fsq_id': '5cddd35316fa04002c29d369',
#                                                'name': 'The Office Of '
#                                                        'Institutional '
#                                                        'Diversity, Equity, '
#                                                        'Advocacy And '
#                                                        'Leadership'},
#                                               {'fsq_id': '501149f4e4b035d9f34657ab',
#                                                'name': 'Morgan Hall'},
#                                               {'fsq_id': '4ade0c06f964a520a86721e3',
#                                                'name': 'Anderson Hall'},
#                                               {'fsq_id': '4b992892f964a5209a6535e3',
#                                                'name': 'Alpha Kappa Lambda'},
#                                               {'fsq_id': '4db0c2a3f7b1bd003acfe853',
#                                                'name': 'McGonigle Hall'},
#                                               {'fsq_id': '4adf15a5f964a520747721e3',
#                                                'name': '7-Eleven'},
#                                               {'fsq_id': '4b153c65f964a520aca923e3',
#                                                'name': 'Barton Hall'},
#                                               {'fsq_id': '4b56069df964a52096fc27e3',
#                                                'name': 'Master Wok'},
#                                               {'fsq_id': '4bb3a16feb3e9521ac6acb0a',
#                                                'name': 'Geasey Field at Temple '
#                                                        'University'},
#                                               {'fsq_id': '4d82de665ad3a0937a1db0fd',
#                                                'name': 'Kappa Delta Rho'},
#                                               {'fsq_id': '4c54155a5b8395215c96be31',
#                                                'name': 'The Conwell Inn'},
#                                               {'fsq_id': '503fd04ae4b01c1808833b88',
#                                                'name': 'Subway'},
#                                               {'fsq_id': '4c23796411de20a13f7386ce',
#                                                'name': 'Conwell Hall'},
#                                               {'fsq_id': '4c7d83c4d461a143546c7df5',
#                                                'name': 'Temple University'},
#                                               {'fsq_id': '4b01e998f964a520854622e3',
#                                                'name': 'The Tech Center'},
#                                               {'fsq_id': '4c7c2d18df08a1cd02b3e25d',
#                                                'name': 'Randall Theater'},
#                                               {'fsq_id': '4a9ea10cf964a520ac3a20e3',
#                                                'name': 'Tyler School of Art'},
#                                               {'fsq_id': '4ade320ff964a520d07321e3',
#                                                'name': 'Johnson & Hardwick'},
#                                               {'fsq_id': '4ee4101cbe7b4845a3f8f18a',
#                                                'name': 'Ato'},
#                                               {'fsq_id': '4ba44fc0f964a5200b9538e3',
#                                                'name': 'White Hall - Temple '
#                                                        'University'},
#                                               {'fsq_id': '4b7052b1f964a520a3122de3',
#                                                'name': 'Biology Life Sciences '
#                                                        'Building'},
#                                               {'fsq_id': '4e2ed75fa8092ca5c3793ab4',
#                                                'name': 'Diamond Dollars / '
#                                                        'OWLcard Office'},
#                                               {'fsq_id': '507c37a3e4b025807b2c0131',
#                                                'name': 'Fox School of Business '
#                                                        'and Management'},
#                                               {'fsq_id': '4b9e7266f964a5209ce436e3',
#                                                'name': 'Hall Wachman'},
#                                               {'fsq_id': '4b53cf4ff964a5200eac27e3',
#                                                'name': 'University Village'},
#                                               {'fsq_id': '4add3cdff964a520b76421e3',
#                                                'name': 'Peabody Hall'},
#                                               {'fsq_id': '4b2a63e1f964a5202fa824e3',
#                                                'name': "Maxi's Pizza Subs and "
#                                                        'Bar'},
#                                               {'fsq_id': '4ee9f93b29c220d20e698daf',
#                                                'name': 'Conwell Hall Undergrad '
#                                                        'Admissions'},
#                                               {'fsq_id': '4b2545fcf964a5201e6f24e3',
#                                                'name': 'The Liacouras Center'},
#                                               {'fsq_id': '4b27a49af964a520168824e3',
#                                                'name': 'Gladfelter Hall'},
#                                               {'fsq_id': '4e96f8385503e24777d0cfe3',
#                                                'name': 'Owl Statue'},
#                                               {'fsq_id': '4d409669915a370499e9167f',
#                                                'name': 'Temple University '
#                                                        'Bookstore'},
#                                               {'fsq_id': '4f271e39e4b04b55281105ab',
#                                                'name': 'Kiva Auditorium'},
#                                               {'fsq_id': '4cfd5845feec6dcba58b5136',
#                                                'name': 'Mcgonigle Training '
#                                                        'Room'},
#                                               {'fsq_id': '599f88f8db1d817a92f74929',
#                                                'name': 'Jamba'},
#                                               {'fsq_id': '4b56fbcff964a520bf2128e3',
#                                                'name': 'Ritter Hall Annex'},
#                                               {'fsq_id': '4d82c3545ad3a0932b37aefd',
#                                                'name': 'Phi Kappa Theta'},
#                                               {'fsq_id': '4b9edef1f964a520800737e3',
#                                                'name': 'Temple University: '
#                                                        '1940 Residence Hall'},
#                                               {'fsq_id': '4e5902df1495a89112782ada',
#                                                'name': 'Temple Field Hockey '
#                                                        'Field'},
#                                               {'fsq_id': '4cb342ad1463a1434741b3a9',
#                                                'name': 'Kappa Alpha Psi '
#                                                        'Fraternity'},
#                                               {'fsq_id': '4ad32f5ff964a52051e320e3',
#                                                'name': 'Temple University Law '
#                                                        'Library'},
#                                               {'fsq_id': '4be4add9d4f7c9b6db872420',
#                                                'name': 'Honickman Learning '
#                                                        'Center and Comcast '
#                                                        'Technology Labs'},
#                                               {'fsq_id': '4c8e323f88ba9521a6abcd62',
#                                                'name': 'Temple Performing Arts '
#                                                        'Center'},
#                                               {'fsq_id': '4bb3b2f9a32876b09d1502fe',
#                                                'name': 'Engineering and '
#                                                        'Architecture'},
#                                               {'fsq_id': '4adf0419f964a520197721e3',
#                                                'name': 'Alter Hall'},
#                                               {'fsq_id': '4e80bef8f5b9ea411fb58a1f',
#                                                'name': 'Temple Hillel'},
#                                               {'fsq_id': '4ae09512f964a5209a8021e3',
#                                                'name': 'Tuttleman Learning '
#                                                        'Center'},
#                                               {'fsq_id': '4c7d5b1ed65437046321c0a2',
#                                                'name': 'Kappa Sigma House'},
#                                               {'fsq_id': '4b181e72f964a52044cd23e3',
#                                                'name': 'Beury Hall'},
#                                               {'fsq_id': '4d99dad50caaa143457dceb3',
#                                                'name': 'Temple Triangle '
#                                                        'Apartments'},
#                                               {'fsq_id': '4c24e6f8136d20a1779be261',
#                                                'name': 'Barrack Hall'},
#                                               {'fsq_id': '4bb2b17deb3e9521266cca0a',
#                                                'name': 'Presser Hall'},
#                                               {'fsq_id': '4d4b3c21afc5236ac5822d90',
#                                                'name': 'Pearson Pool'},
#                                               {'fsq_id': '4c46f938972c0f477b3a2221',
#                                                'name': 'Sullivan Hall'},
#                                               {'fsq_id': '4adfa098f964a520497c21e3',
#                                                'name': 'Howard Gittis Student '
#                                                        'Center'},
#                                               {'fsq_id': '4e57f3bbfa76435f0bd69172',
#                                                'name': 'MCPC'},
#                                               {'fsq_id': '4b9e2fb5f964a52042d036e3',
#                                                'name': 'Mitten Hall'},
#                                               {'fsq_id': '4b2a5db4f964a520d4a724e3',
#                                                'name': 'Saxbys Coffee'},
#                                               {'fsq_id': '4c296cb69eb19521afb92959',
#                                                'name': 'Department of '
#                                                        'Journalism'},
#                                               {'fsq_id': '4c7d014ea141b1f7ab996c79',
#                                                'name': 'Pearson Hall'},
#                                               {'fsq_id': '4e136626ae602afe96ce72bb',
#                                                'name': 'Wheel Thing Store'},
#                                               {'fsq_id': '4ae7a607f964a5200fad21e3',
#                                                'name': 'IBC Student Rec '
#                                                        'Center'},
#                                               {'fsq_id': '4ba0dfc0f964a520c18337e3',
#                                                'name': 'The Bagel Hut'},
#                                               {'fsq_id': '4bec35e5415e20a16b3ee7bb',
#                                                'name': 'Student Pavilion'},
#                                               {'fsq_id': '4c6d57e87bfe199c4065dbce',
#                                                'name': 'Edward H. Rosen '
#                                                        'Center'},
#                                               {'fsq_id': '4e529e1818381362f73139d2',
#                                                'name': 'Temple University '
#                                                        'Honors Lounge'},
#                                               {'fsq_id': '4bc35eb9461576b040897e32',
#                                                'name': 'Speakman Hall'},
#                                               {'fsq_id': '4c49fb78712ac9284472ca6a',
#                                                'name': 'Phi Sigma Sigma '
#                                                        'Sorority'},
#                                               {'fsq_id': '4bb4a60c8786ef3bfe746533',
#                                                'name': 'Weiss Hall - Temple '
#                                                        'University'},
#                                               {'fsq_id': '4e5fddf0ae601ef79d63f808',
#                                                'name': 'CLA Advising Center'},
#                                               {'fsq_id': '4adf1d98f964a520ae7721e3',
#                                                'name': 'Ritter Annex'},
#                                               {'fsq_id': '4af23403f964a52088e621e3',
#                                                'name': 'Temple Towers'},
#                                               {'fsq_id': '4c4f215fea24c9b6d5b5d516',
#                                                'name': "Founder's Garden"},
#                                               {'fsq_id': '4b621ad4f964a520be352ae3',
#                                                'name': 'H.E.A.R.T. Office'},
#                                               {'fsq_id': '4dac3760fa8cc764975da0f1',
#                                                'name': 'Temple University '
#                                                        'Occupational Therapy'},
#                                               {'fsq_id': '53282278498e46e4f376c24e',
#                                                'name': 'Science Education & '
#                                                        'Research Center'},
#                                               {'fsq_id': '4bd76e7809ecb713e7df467c',
#                                                'name': 'AEPi'},
#                                               {'fsq_id': '4ba100a4f964a520e88d37e3',
#                                                'name': 'Beury Beach'},
#                                               {'fsq_id': '4b9fa09bf964a520e02f37e3',
#                                                'name': 'The Bell Tower - '
#                                                        'Temple University'}]},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#                                        'suffix': '.png'},
#                               'id': 12013,
#                               'name': 'College and University'}],
#               'chains': [],
#               'distance': 2091,
#               'fsq_id': '4f5d4980e4b04fe10f8b86b7',
#               'geocodes': {'drop_off': {'latitude': 39.983455,
#                                         'longitude': -75.152998},
#                            'main': {'latitude': 39.983571,
#                                     'longitude': -75.15352},
#                            'roof': {'latitude': 39.983571,
#                                     'longitude': -75.15352}},
#               'link': '/v3/places/4f5d4980e4b04fe10f8b86b7',
#               'location': {'address': '2001 N 13th St',
#                            'census_block': '421010377001010',
#                            'country': 'US',
#                            'cross_street': 'Norris',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '2001 N 13th St (Norris), '
#                                                 'Philadelphia, PA 19122',
#                            'locality': 'Philadelphia',
#                            'postcode': '19122',
#                            'region': 'PA'},
#               'name': 'Boyer College of Music and Dance - Temple University',
#               'related_places': {},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#                                        'suffix': '.png'},
#                               'id': 12013,
#                               'name': 'College and University'}],
#               'chains': [],
#               'distance': 2119,
#               'fsq_id': '4bb4a60c8786ef3bfe746533',
#               'geocodes': {'main': {'latitude': 39.979309,
#                                     'longitude': -75.157336},
#                            'roof': {'latitude': 39.979309,
#                                     'longitude': -75.157336}},
#               'link': '/v3/places/4bb4a60c8786ef3bfe746533',
#               'location': {'address': '1715 N Broad St',
#                            'census_block': '421010146002002',
#                            'country': 'US',
#                            'cross_street': 'Cecil B. Moore',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1715 N Broad St (Cecil B. '
#                                                 'Moore), Philadelphia, PA '
#                                                 '19122',
#                            'locality': 'Philadelphia',
#                            'postcode': '19122',
#                            'region': 'PA'},
#               'name': 'Weiss Hall - Temple University',
#               'related_places': {'parent': {'fsq_id': '415c9e00f964a520511d1fe3',
#                                             'name': 'Temple University'}},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/administrativebuilding_',
#                                        'suffix': '.png'},
#                               'id': 12015,
#                               'name': 'College Administrative Building'}],
#               'chains': [],
#               'distance': 2184,
#               'fsq_id': '4b9e2fb5f964a52042d036e3',
#               'geocodes': {'main': {'latitude': 39.981899,
#                                     'longitude': -75.156727},
#                            'roof': {'latitude': 39.981899,
#                                     'longitude': -75.156727}},
#               'link': '/v3/places/4b9e2fb5f964a52042d036e3',
#               'location': {'address': '1913 N Broad St',
#                            'census_block': '421010377001013',
#                            'country': 'US',
#                            'cross_street': 'Temple University',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1913 N Broad St (Temple '
#                                                 'University), Philadelphia, PA '
#                                                 '19122',
#                            'locality': 'Philadelphia',
#                            'postcode': '19122',
#                            'region': 'PA'},
#               'name': 'Mitten Hall',
#               'related_places': {'children': [{'fsq_id': '5991be5a5c68384c0ee4bae8',
#                                                'name': 'Pre-Professional '
#                                                        'Health Studies'},
#                                               {'fsq_id': '4d939643484d6ea8cb847e30',
#                                                'name': 'HEART Office'}],
#                                  'parent': {'fsq_id': '415c9e00f964a520511d1fe3',
#                                             'name': 'Temple University'}},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#                                        'suffix': '.png'},
#                               'id': 12027,
#                               'name': 'College Gym'}],
#               'chains': [],
#               'distance': 2255,
#               'fsq_id': '4ae7a607f964a5200fad21e3',
#               'geocodes': {'main': {'latitude': 39.978775,
#                                     'longitude': -75.160142},
#                            'roof': {'latitude': 39.978775,
#                                     'longitude': -75.160142}},
#               'link': '/v3/places/4ae7a607f964a5200fad21e3',
#               'location': {'address': '1500 Cecil B Moore Ave',
#                            'census_block': '421010147002009',
#                            'country': 'US',
#                            'cross_street': 'at Temple University',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1500 Cecil B Moore Ave (at '
#                                                 'Temple University), '
#                                                 'Philadelphia, PA 19121',
#                            'locality': 'Philadelphia',
#                            'postcode': '19121',
#                            'region': 'PA'},
#               'name': 'IBC Student Rec Center',
#               'related_places': {'parent': {'fsq_id': '415c9e00f964a520511d1fe3',
#                                             'name': 'Temple University'}},
#               'timezone': 'America/New_York'}]}

# %%
# check how to access distances
col['results'][0]['distance']
# Out:
# 1867

# %%
# getting each college's distance from each station
# list to store each location's data
college_loc = []

# iterating through each lat-lng pair
for index, row in ph_bikes.iterrows():
    lat = row['latitude']
    lng = row['longitude']

    # call and append
    location = get_fsq(latitude=lat, longitude=lng, radius=radius, api_key=FOURSQUARE_KEY, categories=categories)

    # nested loop to iterate through colleges for each location
    if 'results' in location and len(location['results']) > 0:
        first_distance = location['results'][0]['distance']
        college_loc.append(first_distance)
    else:
        # Handle cases where no centers are returned
        college_loc.append('NA')

# %%
len(college_loc)
# Out:
# 233

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
# Convert the data into a DataFrame and assign ID to aid when merging

fsq_uni = pd.DataFrame(college_loc)
fsq_uni = fsq_uni.rename_axis("ID").reset_index()

# %%
# Renaming the columns

fsq_uni.columns = ["ID", "fsq_college_dist"]
fsq_uni.head()
# Out:
#    ID  fsq_college_dist
# 0   0              1555
# 1   1              1732
# 2   2              2069
# 3   3              1579
# 4   4              2114

# %%
csv_file_path = 'fsq_uni.csv'

# Save the DataFrame to a CSV file
fsq_uni.to_csv(csv_file_path, index=False)

# %% [markdown]
# #
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
# Function for API call to Yelp

def get_yelp(latitude, longitude, radius, api_key, categories):
    url = "https://api.yelp.com/v3/businesses/search"

    headers = {
        "accept": "application/json",
        "Authorization": yelp_key
    }

    params = {
        "latitude": latitude,
        "longitude": longitude,
        "categories": categories,
        "sort_by": sort_by
    }

    response = requests.get(url, headers=headers, params=params)

    return response.json()

# %%
test = get_yelp(latitude=39.97195, longitude=-75.13445, radius=None, api_key=yelp_key, categories="fitness")
pprint(test)
# Out:
# {'businesses': [{'alias': 'amrita-yoga-and-wellness-philadelphia',
#                  'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#                                 {'alias': 'pilates', 'title': 'Pilates'}],
#                  'coordinates': {'latitude': 39.96885, 'longitude': -75.1346},
#                  'display_phone': '(267) 928-3176',
#                  'distance': 310.26798197383675,
#                  'id': 'mtcgWB-WYipeGkJtaplEjg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/39vpNv0jw3NBqtUUFSc3rg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1204 Frankford Ave',
#                               'address2': 'Fl 2',
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1204 Frankford Ave',
#                                                   'Fl 2',
#                                                   'Philadelphia, PA 19125'],
#                               'state': 'PA',
#                               'zip_code': '19125'},
#                  'name': 'Amrita Yoga & Wellness',
#                  'phone': '+12679283176',
#                  'rating': 4.5,
#                  'review_count': 98,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/amrita-yoga-and-wellness-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'tufas-boulder-lounge-philadelphia',
#                  'categories': [{'alias': 'rock_climbing',
#                                  'title': 'Rock Climbing'},
#                                 {'alias': 'gyms', 'title': 'Gyms'}],
#                  'coordinates': {'latitude': 39.97596, 'longitude': -75.14417},
#                  'display_phone': '(215) 360-3999',
#                  'distance': 924.2171155008723,
#                  'id': '_dDG2NGsUnMuxpx63O61RQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7Mn8CTCb02scc3QgOfsL0g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1614 N 5th St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1614 N 5th St',
#                                                   'Philadelphia, PA 19122'],
#                               'state': 'PA',
#                               'zip_code': '19122'},
#                  'name': 'Tufas Boulder Lounge',
#                  'phone': '+12153603999',
#                  'rating': 4.5,
#                  'review_count': 34,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/tufas-boulder-lounge-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'balance-studios-philadelphia-7',
#                  'categories': [{'alias': 'martialarts',
#                                  'title': 'Martial Arts'},
#                                 {'alias': 'boxing', 'title': 'Boxing'},
#                                 {'alias': 'yoga', 'title': 'Yoga'}],
#                  'coordinates': {'latitude': 39.970645904541,
#                                  'longitude': -75.1347274780273},
#                  'display_phone': '(215) 988-9347',
#                  'distance': 146.68732620801984,
#                  'id': '0Z4psJe-0zSggtZjSaOJ9g',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FGhyHWyGAf_mBuOQiJpTPA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1314 Frankford Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1314 Frankford Ave',
#                                                   'Philadelphia, PA 19125'],
#                               'state': 'PA',
#                               'zip_code': '19125'},
#                  'name': 'Balance Studios',
#                  'phone': '+12159889347',
#                  'rating': 5.0,
#                  'review_count': 14,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/balance-studios-philadelphia-7?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'orangetheory-fitness-northern-liberties-philadelphia',
#                  'categories': [{'alias': 'bootcamps', 'title': 'Boot Camps'},
#                                 {'alias': 'gyms', 'title': 'Gyms'},
#                                 {'alias': 'healthtrainers',
#                                  'title': 'Trainers'}],
#                  'coordinates': {'latitude': 39.9665763827049,
#                                  'longitude': -75.1393067128976},
#                  'display_phone': '(267) 331-4445',
#                  'distance': 726.8605388607293,
#                  'id': 'nxV0qNngBHkOBm3rer9E-w',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OEr5aZEKoRCSStrxcz2Y-w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1050 N Hancock St',
#                               'address2': 'Ste 58',
#                               'address3': None,
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1050 N Hancock St',
#                                                   'Ste 58',
#                                                   'Philadelphia, PA 19123'],
#                               'state': 'PA',
#                               'zip_code': '19123'},
#                  'name': 'Orangetheory Fitness Northern Liberties',
#                  'phone': '+12673314445',
#                  'rating': 5.0,
#                  'review_count': 34,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/orangetheory-fitness-northern-liberties-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'sculpere-studio-philadelphia',
#                  'categories': [{'alias': 'yoga', 'title': 'Yoga'},
#                                 {'alias': 'pilates', 'title': 'Pilates'},
#                                 {'alias': 'barreclasses',
#                                  'title': 'Barre Classes'}],
#                  'coordinates': {'latitude': 39.964461,
#                                  'longitude': -75.141027},
#                  'display_phone': '(215) 592-1200',
#                  'distance': 1003.7939020066746,
#                  'id': 'u_X7JlkEChx8UsxI_S7deg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/C4FOm7Gtca0V7OZCfqRFfQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '209 Poplar St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['209 Poplar St',
#                                                   'Philadelphia, PA 19123'],
#                               'state': 'PA',
#                               'zip_code': '19123'},
#                  'name': 'Sculpere Studio',
#                  'phone': '+12155921200',
#                  'rating': 5.0,
#                  'review_count': 28,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sculpere-studio-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'formation-sauna-wellness-philadelphia',
#                  'categories': [{'alias': 'saunas', 'title': 'Saunas'},
#                                 {'alias': 'massage', 'title': 'Massage'},
#                                 {'alias': 'meditationcenters',
#                                  'title': 'Meditation Centers'}],
#                  'coordinates': {'latitude': 39.963721, 'longitude': -75.14337},
#                  'display_phone': '(267) 324-3193',
#                  'distance': 1183.819507812119,
#                  'id': '8CSTxca6S_c6nr4z_tY0bQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/T4TBwfawhptTL0c-5GuHAA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '305 Brown St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['305 Brown St',
#                                                   'Philadelphia, PA 19123'],
#                               'state': 'PA',
#                               'zip_code': '19123'},
#                  'name': 'FORMATION sauna + wellness',
#                  'phone': '+12673243193',
#                  'rating': 5.0,
#                  'review_count': 23,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/formation-sauna-wellness-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'war-horse-barbell-philadelphia',
#                  'categories': [{'alias': 'gyms', 'title': 'Gyms'}],
#                  'coordinates': {'latitude': 39.962966, 'longitude': -75.14064},
#                  'display_phone': '(267) 254-2844',
#                  'distance': 1125.5855136945206,
#                  'id': 'rytqWB6v6AAAxZiqy7Flww',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/MPasmYdvY5EhylmkqHyUHg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '801-5 N 2nd St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['801-5 N 2nd St',
#                                                   'Philadelphia, PA 19123'],
#                               'state': 'PA',
#                               'zip_code': '19123'},
#                  'name': 'War Horse Barbell',
#                  'phone': '+12672542844',
#                  'rating': 5.0,
#                  'review_count': 33,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/war-horse-barbell-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'tuck-barre-and-yoga-philadelphia-2',
#                  'categories': [{'alias': 'barreclasses',
#                                  'title': 'Barre Classes'},
#                                 {'alias': 'yoga', 'title': 'Yoga'}],
#                  'coordinates': {'latitude': 39.967461,
#                                  'longitude': -75.136992},
#                  'display_phone': '',
#                  'distance': 540.8570744418631,
#                  'id': 'Uvpx41yn-0osCsbM4zvPxQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Mdm-YnzMsqxI-omCHbNRmQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1100 N Front St',
#                               'address2': 'Ste 104',
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1100 N Front St',
#                                                   'Ste 104',
#                                                   'Philadelphia, PA 19123'],
#                               'state': 'PA',
#                               'zip_code': '19123'},
#                  'name': 'Tuck Barre & Yoga',
#                  'phone': '',
#                  'rating': 5.0,
#                  'review_count': 7,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/tuck-barre-and-yoga-philadelphia-2?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'the-training-station-gym-philadelphia',
#                  'categories': [{'alias': 'gyms', 'title': 'Gyms'}],
#                  'coordinates': {'latitude': 39.9616587,
#                                  'longitude': -75.1474259},
#                  'display_phone': '(215) 964-9558',
#                  'distance': 1591.3403022937969,
#                  'id': '3yJncsrrB2Jd0Ax7imaK-w',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KK991rsj969OH9nkBfTXtQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '533 Spring Garden St, D1',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['533 Spring Garden St, D1',
#                                                   'Philadelphia, PA 19123'],
#                               'state': 'PA',
#                               'zip_code': '19123'},
#                  'name': 'The Training Station Gym',
#                  'phone': '+12159649558',
#                  'rating': 4.5,
#                  'review_count': 29,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-training-station-gym-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'motherheart-studio-philadelphia',
#                  'categories': [{'alias': 'yoga', 'title': 'Yoga'}],
#                  'coordinates': {'latitude': 39.9770571,
#                                  'longitude': -75.1272832},
#                  'display_phone': '(484) 885-9081',
#                  'distance': 833.9316425458196,
#                  'id': 'Lb11i2WxB9p7r24Srv7c4w',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xZTd-WWR5TRM8z84zQ6PDQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2359 E Susquehanna St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['2359 E Susquehanna St',
#                                                   'Philadelphia, PA 19125'],
#                               'state': 'PA',
#                               'zip_code': '19125'},
#                  'name': 'MotherHeart Studio',
#                  'phone': '+14848859081',
#                  'rating': 5.0,
#                  'review_count': 19,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/motherheart-studio-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'city-fitness-fishtown-philadelphia',
#                  'categories': [{'alias': 'gyms', 'title': 'Gyms'},
#                                 {'alias': 'healthtrainers',
#                                  'title': 'Trainers'}],
#                  'coordinates': {'latitude': 39.97255, 'longitude': -75.134584},
#                  'display_phone': '(215) 302-4444',
#                  'distance': 70.63432495496218,
#                  'id': 'pQUrSvni9ReYTfDZtg2BRw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OpNSLx5ELIz5k90-7r5nNg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1428 Frankford Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1428 Frankford Ave',
#                                                   'Philadelphia, PA 19125'],
#                               'state': 'PA',
#                               'zip_code': '19125'},
#                  'name': 'CIty Fitness - Fishtown',
#                  'phone': '+12153024444',
#                  'rating': 2.5,
#                  'review_count': 54,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/city-fitness-fishtown-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'stay-fly-muay-thai-philadelphia',
#                  'categories': [{'alias': 'muaythai', 'title': 'Muay Thai'}],
#                  'coordinates': {'latitude': 39.97238759524974,
#                                  'longitude': -75.14050229098817},
#                  'display_phone': '(215) 300-0031',
#                  'distance': 518.0354528825181,
#                  'id': 'i2PC2TcmNGhzeb7---fPFw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EPQg1vyNG4vfV8RHE3Uw8g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1360 N American St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1360 N American St',
#                                                   'Philadelphia, PA 19122'],
#                               'state': 'PA',
#                               'zip_code': '19122'},
#                  'name': 'Stay Fly Muay Thai',
#                  'phone': '+12153000031',
#                  'rating': 4.5,
#                  'review_count': 18,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/stay-fly-muay-thai-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'philly-self-defense-philadelphia',
#                  'categories': [{'alias': 'boxing', 'title': 'Boxing'},
#                                 {'alias': 'martialarts',
#                                  'title': 'Martial Arts'}],
#                  'coordinates': {'latitude': 39.971149,
#                                  'longitude': -75.135239},
#                  'display_phone': '(267) 702-6614',
#                  'distance': 109.72346743801235,
#                  'id': '-ooQlxiWp21ubVBlLSzM2w',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/M7t_Zcp0mBB2uA_Y3mBtTA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1333 N Front St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1333 N Front St',
#                                                   'Philadelphia, PA 19122'],
#                               'state': 'PA',
#                               'zip_code': '19122'},
#                  'name': 'Philly Self Defense',
#                  'phone': '+12677026614',
#                  'rating': 5.0,
#                  'review_count': 6,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/philly-self-defense-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'revolution-fitness-factory-philadelphia',
#                  'categories': [{'alias': 'bootcamps', 'title': 'Boot Camps'},
#                                 {'alias': 'healthtrainers',
#                                  'title': 'Trainers'}],
#                  'coordinates': {'latitude': 39.974968,
#                                  'longitude': -75.144123},
#                  'display_phone': '(866) 738-3481',
#                  'distance': 889.9637268431378,
#                  'id': 'CMLS5r0rOAWqlnu5lnC0TA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/srQScKIxNlKL_3-p57Dhig/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1516 N 5th St',
#                               'address2': 'Unit 104',
#                               'address3': None,
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1516 N 5th St',
#                                                   'Unit 104',
#                                                   'Philadelphia, PA 19122'],
#                               'state': 'PA',
#                               'zip_code': '19122'},
#                  'name': 'Revolution Fitness Factory',
#                  'phone': '+18667383481',
#                  'rating': 5.0,
#                  'review_count': 9,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/revolution-fitness-factory-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'crossfit-novem-philadelphia-3',
#                  'categories': [{'alias': 'circuittraininggyms',
#                                  'title': 'Circuit Training Gyms'},
#                                 {'alias': 'intervaltraininggyms',
#                                  'title': 'Interval Training Gyms'}],
#                  'coordinates': {'latitude': 39.9763823,
#                                  'longitude': -75.1352466},
#                  'display_phone': '(215) 291-2968',
#                  'distance': 497.50134319661527,
#                  'id': 'p4hIzUXyP0ENRIEKcihhDA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TF47SjU8Kb7FDLNjblnPFA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1732 N Howard St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1732 N Howard St',
#                                                   'Philadelphia, PA 19122'],
#                               'state': 'PA',
#                               'zip_code': '19122'},
#                  'name': 'Crossfit Novem',
#                  'phone': '+12152912968',
#                  'rating': 5.0,
#                  'review_count': 40,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/crossfit-novem-philadelphia-3?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'estilo-dance-studio-philadelphia',
#                  'categories': [{'alias': 'theater',
#                                  'title': 'Performing Arts'},
#                                 {'alias': 'dance_schools',
#                                  'title': 'Dance Schools'},
#                                 {'alias': 'dancestudio',
#                                  'title': 'Dance Studios'}],
#                  'coordinates': {'latitude': 39.9795583,
#                                  'longitude': -75.1298171},
#                  'display_phone': '(267) 317-8849',
#                  'distance': 933.5770653494967,
#                  'id': 'gsiurmoX2jYAFzw27NGddg',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qfaIpC3MRlpd1ig2KIsXGQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2036 Frankford Ave',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['2036 Frankford Ave',
#                                                   'Philadelphia, PA 19124'],
#                               'state': 'PA',
#                               'zip_code': '19124'},
#                  'name': 'Estilo Dance Studio',
#                  'phone': '+12673178849',
#                  'rating': 5.0,
#                  'review_count': 11,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/estilo-dance-studio-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'barre3-philadelphia-rittenhouse-square-philadelphia',
#                  'categories': [{'alias': 'barreclasses',
#                                  'title': 'Barre Classes'},
#                                 {'alias': 'yoga', 'title': 'Yoga'},
#                                 {'alias': 'pilates', 'title': 'Pilates'}],
#                  'coordinates': {'latitude': 39.95031, 'longitude': -75.16578},
#                  'display_phone': '(267) 639-6704',
#                  'distance': 3594.4544596401665,
#                  'id': 'r1XZyqd0JU4GGJhBBGcG7A',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/78vz0le1ZpI04feEJBjYag/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1500 Sansom St',
#                               'address2': 'Fl 4',
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1500 Sansom St',
#                                                   'Fl 4',
#                                                   'Philadelphia, PA 19102'],
#                               'state': 'PA',
#                               'zip_code': '19102'},
#                  'name': 'barre3 Philadelphia - Rittenhouse Square',
#                  'phone': '+12676396704',
#                  'rating': 5.0,
#                  'review_count': 69,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/barre3-philadelphia-rittenhouse-square-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'solidcore-center-city-philadelphia-3',
#                  'categories': [{'alias': 'pilates', 'title': 'Pilates'}],
#                  'coordinates': {'latitude': 39.94987, 'longitude': -75.15331},
#                  'display_phone': '(267) 800-2720',
#                  'distance': 2935.5789825601837,
#                  'id': 'wPgAvTOsSlkRBi5W6F7wUg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3yJup46ES-KlsvTD0qnb4A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '725 Chestnut St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['725 Chestnut St',
#                                                   'Philadelphia, PA 19106'],
#                               'state': 'PA',
#                               'zip_code': '19106'},
#                  'name': 'Solidcore - Center City',
#                  'phone': '+12678002720',
#                  'rating': 4.5,
#                  'review_count': 53,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/solidcore-center-city-philadelphia-3?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'unite-fitness-rittenhouse-philadelphia',
#                  'categories': [{'alias': 'healthtrainers',
#                                  'title': 'Trainers'},
#                                 {'alias': 'intervaltraininggyms',
#                                  'title': 'Interval Training Gyms'}],
#                  'coordinates': {'latitude': 39.9524414,
#                                  'longitude': -75.1735548},
#                  'display_phone': '(267) 534-3230',
#                  'distance': 3974.9504547843076,
#                  'id': 'K7vT-aZRtl6V4IjpRXaCNQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4txQtdNJrrYe7IoPmqA6Pw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '26 S 20th St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['26 S 20th St',
#                                                   'Philadelphia, PA 19103'],
#                               'state': 'PA',
#                               'zip_code': '19103'},
#                  'name': 'Unite Fitness - Rittenhouse',
#                  'phone': '+12675343230',
#                  'rating': 5.0,
#                  'review_count': 33,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/unite-fitness-rittenhouse-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'philly-dance-fitness-philadelphia',
#                  'categories': [{'alias': 'dancestudio',
#                                  'title': 'Dance Studios'},
#                                 {'alias': 'gyms', 'title': 'Gyms'},
#                                 {'alias': 'pilates', 'title': 'Pilates'}],
#                  'coordinates': {'latitude': 39.95225, 'longitude': -75.1727},
#                  'display_phone': '(215) 645-2717',
#                  'distance': 3926.1713974765526,
#                  'id': 'iuKzxuAgf2ttgOyxyLHEMQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3bOAXGi2b6tCfQbmxatZwQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1923 Chestnut St',
#                               'address2': 'Fl 2',
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1923 Chestnut St',
#                                                   'Fl 2',
#                                                   'Philadelphia, PA 19103'],
#                               'state': 'PA',
#                               'zip_code': '19103'},
#                  'name': 'Philly Dance Fitness',
#                  'phone': '+12156452717',
#                  'rating': 5.0,
#                  'review_count': 79,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/philly-dance-fitness-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'}],
#  'region': {'center': {'latitude': 39.97195, 'longitude': -75.13445}},
#  'total': 436}

# %% [markdown]
# ### Fitness POI

# %%
# assign values for fitness POI using distance
latitude = ph_bikes['latitude']
longitude = ph_bikes['longitude']
categories = "fitness"
sort_by = "distance"

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
# getting each fitness center's distance from each station
# list to store each location's data
fitness_loc = []

# iterating through each lat-lng pair
for index, row in ph_bikes.iterrows():
    lat = row['latitude']
    lng = row['longitude']

    # call and append
    location = get_yelp(latitude=lat, longitude=lng, radius=1000, api_key=yelp_key2, categories=categories)

    # nested loop to iterate through centers for each location
    if 'businesses' in location and len(location['businesses']) > 0:
        first_distance = location['businesses'][0]['distance']
        fitness_loc.append(first_distance)
    else:
        # Handle cases where no centers are returned
        fitness_loc.append(NA)

# %%
len(fitness_loc)
# Out:
# 233

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
# Convert the data into a DataFrame and assign ID to aid when merging

yelp_fit = pd.DataFrame(fitness_loc)
yelp_fit = yelp_fit.rename_axis("ID").reset_index()

# %%
# Renaming the columns

yelp_fit.columns = ["ID", "yelp_center_dist"]
yelp_fit.head()
# Out:
#    ID  yelp_center_dist
# 0   0        206.798597
# 1   1        130.753256
# 2   2        794.358688
# 3   3        165.841893
# 4   4        711.265245

# %%
csv_file_path = 'yelp_fit.csv'

# Save the DataFrame to a CSV file
yelp_fit.to_csv(csv_file_path, index=False)

# %% [markdown]
# ###
# ### College POI

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
# assign values for college POI
latitude = ph_bikes['latitude']
longitude = ph_bikes['longitude']
categories = "collegeuniv"
sort_by = "distance"

# %%
# getting each college's distance from each station

# list to store each location's data
college_dist = []

# iterating through each lat-lng pair
for index, row in ph_bikes.iterrows():
    lat = row['latitude']
    lng = row['longitude']

    # call and append
    location = get_yelp(latitude=lat, longitude=lng, radius=None, api_key=yelp_key, categories=categories)

    # nested loop to iterate through colleges for each location
    if 'businesses' in location and len(location['businesses']) > 0:
        first_distance = location['businesses'][0]['distance']
        college_dist.append(first_distance)
    else:
        # Handle cases where no colleges are returned
        college_dist.append(NA)

# %%
len(college_dist)
# Out:
# 233

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
# Convert the data into a DataFrame and assign ID to aid when merging

yelp_uni = pd.DataFrame(college_dist)
yelp_uni = yelp_uni.rename_axis("ID").reset_index()

# %%
# Renaming the columns

yelp_uni.columns = ["ID", "yelp_college_dist"]
yelp_uni.head()
# Out:
#    ID  yelp_college_dist
# 0   0        1331.446597
# 1   1        1706.096309
# 2   2        2282.529810
# 3   3        1808.390164
# 4   4        2707.043477

# %%
csv_file_path = 'yelp_uni.csv'

# Save the DataFrame to a CSV file
yelp_uni.to_csv(csv_file_path, index=False)

# %% [markdown]
# #
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# #### *Comparing one lat-lng point for restaurants on the Yelp and Foursquare API*

# %%
# restaurant testing - Foursquare
sort = "relevance"

fsq_res = get_fsq(latitude=39.97195, longitude=-75.13445, radius=1000, api_key=FOURSQUARE_KEY, categories=13065)
pprint(fsq_res)

# no info on ratings
# Out:
# {'context': {'geo_bounds': {'circle': {'center': {'latitude': 39.97195,
#                                                   'longitude': -75.13445},
#                                        'radius': 1000}}},
#  'results': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#                                        'suffix': '.png'},
#                               'id': 13009,
#                               'name': 'Cocktail Bar'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#                                        'suffix': '.png'},
#                               'id': 13064,
#                               'name': 'Pizzeria'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#                                        'suffix': '.png'},
#                               'id': 13236,
#                               'name': 'Italian Restaurant'}],
#               'chains': [],
#               'distance': 59,
#               'fsq_id': '56fb2e82498ec4440b0aa2e9',
#               'geocodes': {'main': {'latitude': 39.971695,
#                                     'longitude': -75.134998},
#                            'roof': {'latitude': 39.971695,
#                                     'longitude': -75.134998}},
#               'link': '/v3/places/56fb2e82498ec4440b0aa2e9',
#               'location': {'address': '1355 N Front St',
#                            'census_block': '421010144003013',
#                            'country': 'US',
#                            'cross_street': '',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1355 N Front St, '
#                                                 'Philadelphia, PA 19122',
#                            'locality': 'Philadelphia',
#                            'postcode': '19122',
#                            'region': 'PA'},
#               'name': "Wm. Mulherin's Sons",
#               'related_places': {},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#                                        'suffix': '.png'},
#                               'id': 13034,
#                               'name': 'Café'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#                                        'suffix': '.png'},
#                               'id': 13035,
#                               'name': 'Coffee Shop'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13065,
#                               'name': 'Restaurant'}],
#               'chains': [],
#               'distance': 83,
#               'fsq_id': '5427166a498e85a2c0b936b3',
#               'geocodes': {'drop_off': {'latitude': 39.971139,
#                                         'longitude': -75.134416},
#                            'main': {'latitude': 39.971136,
#                                     'longitude': -75.134231},
#                            'roof': {'latitude': 39.971136,
#                                     'longitude': -75.134231}},
#               'link': '/v3/places/5427166a498e85a2c0b936b3',
#               'location': {'address': '1335 Frankford Ave',
#                            'census_block': '421010158004006',
#                            'country': 'US',
#                            'cross_street': 'btwn Mercer & Master St',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1335 Frankford Ave (btwn '
#                                                 'Mercer & Master St), '
#                                                 'Philadelphia, PA 19125',
#                            'locality': 'Philadelphia',
#                            'postcode': '19125',
#                            'region': 'PA'},
#               'name': 'La Colombe Coffee Roasters',
#               'related_places': {},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#                                        'suffix': '.png'},
#                               'id': 13064,
#                               'name': 'Pizzeria'}],
#               'chains': [],
#               'distance': 155,
#               'fsq_id': '5c958f5e2619ee002c1a8470',
#               'geocodes': {'main': {'latitude': 39.970664,
#                                     'longitude': -75.135406},
#                            'roof': {'latitude': 39.970664,
#                                     'longitude': -75.135406}},
#               'link': '/v3/places/5c958f5e2619ee002c1a8470',
#               'location': {'address': '1313 N LEE St',
#                            'census_block': '421010144003013',
#                            'country': 'US',
#                            'cross_street': 'btwn Master & Thompson St',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1313 N LEE St (btwn Master & '
#                                                 'Thompson St), Philadelphia, '
#                                                 'PA 19125',
#                            'locality': 'Philadelphia',
#                            'postcode': '19125',
#                            'region': 'PA'},
#               'name': 'Pizzeria Beddia',
#               'related_places': {},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#                                        'suffix': '.png'},
#                               'id': 13022,
#                               'name': 'Sports Bar'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#                                        'suffix': '.png'},
#                               'id': 13026,
#                               'name': 'BBQ Joint'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13068,
#                               'name': 'American Restaurant'}],
#               'chains': [],
#               'distance': 159,
#               'fsq_id': '507ad324e4b0c101c709028d',
#               'geocodes': {'drop_off': {'latitude': 39.970518,
#                                         'longitude': -75.134431},
#                            'main': {'latitude': 39.970528,
#                                     'longitude': -75.134752},
#                            'roof': {'latitude': 39.970528,
#                                     'longitude': -75.134752}},
#               'link': '/v3/places/507ad324e4b0c101c709028d',
#               'location': {'address': '1308 Frankford Ave',
#                            'census_block': '421010144003028',
#                            'country': 'US',
#                            'cross_street': 'at Thompson St',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1308 Frankford Ave (at '
#                                                 'Thompson St), Philadelphia, '
#                                                 'PA 19125',
#                            'locality': 'Philadelphia',
#                            'postcode': '19125',
#                            'region': 'PA'},
#               'name': 'Bottle Bar East',
#               'related_places': {},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#                                        'suffix': '.png'},
#                               'id': 13263,
#                               'name': 'Japanese Restaurant'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#                                        'suffix': '.png'},
#                               'id': 13315,
#                               'name': 'Noodle Restaurant'}],
#               'chains': [],
#               'distance': 38,
#               'fsq_id': '597397c3851de565cc92bc6d',
#               'geocodes': {'drop_off': {'latitude': 39.972243,
#                                         'longitude': -75.134402},
#                            'main': {'latitude': 39.972245,
#                                     'longitude': -75.134603},
#                            'roof': {'latitude': 39.972245,
#                                     'longitude': -75.134603}},
#               'link': '/v3/places/597397c3851de565cc92bc6d',
#               'location': {'address': '1416 Frankford Ave',
#                            'census_block': '421010144003029',
#                            'country': 'US',
#                            'cross_street': '',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1416 Frankford Ave, '
#                                                 'Philadelphia, PA 19125',
#                            'locality': 'Philadelphia',
#                            'postcode': '19125',
#                            'region': 'PA'},
#               'name': 'Cheu Fishtown',
#               'related_places': {},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13032,
#                               'name': 'Cafe, Coffee, and Tea House'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#                                        'suffix': '.png'},
#                               'id': 13298,
#                               'name': 'Lebanese Restaurant'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#                                        'suffix': '.png'},
#                               'id': 13302,
#                               'name': 'Mediterranean Restaurant'}],
#               'chains': [],
#               'distance': 202,
#               'fsq_id': '5a1edb53da708014e41026a4',
#               'geocodes': {'drop_off': {'latitude': 39.97357,
#                                         'longitude': -75.133666},
#                            'main': {'latitude': 39.973664,
#                                     'longitude': -75.133832},
#                            'roof': {'latitude': 39.973664,
#                                     'longitude': -75.133832}},
#               'link': '/v3/places/5a1edb53da708014e41026a4',
#               'location': {'address': '1528 Frankford Ave',
#                            'census_block': '421010144003000',
#                            'country': 'US',
#                            'cross_street': '',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1528 Frankford Ave, '
#                                                 'Philadelphia, PA 19125',
#                            'locality': 'Philadelphia',
#                            'postcode': '19125',
#                            'region': 'PA'},
#               'name': 'Suraya',
#               'related_places': {},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#                                        'suffix': '.png'},
#                               'id': 13009,
#                               'name': 'Cocktail Bar'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13068,
#                               'name': 'American Restaurant'}],
#               'chains': [],
#               'distance': 256,
#               'fsq_id': '61703e0e75208a675ce0cbd7',
#               'geocodes': {'drop_off': {'latitude': 39.969967,
#                                         'longitude': -75.135904},
#                            'main': {'latitude': 39.970095,
#                                     'longitude': -75.136316},
#                            'roof': {'latitude': 39.970095,
#                                     'longitude': -75.136316}},
#               'link': '/v3/places/61703e0e75208a675ce0cbd7',
#               'location': {'address': '1232 N Front St',
#                            'census_block': '421010144003025',
#                            'country': 'US',
#                            'cross_street': 'at W Thompson St',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1232 N Front St (at W '
#                                                 'Thompson St), Philadelphia, '
#                                                 'PA 19122',
#                            'locality': 'Philadelphia',
#                            'postcode': '19122',
#                            'region': 'PA'},
#               'name': 'Middle Child Clubhouse',
#               'related_places': {'children': []},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#                                        'suffix': '.png'},
#                               'id': 13007,
#                               'name': 'Beer Garden'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'},
#                               'id': 13068,
#                               'name': 'American Restaurant'},
#                              {'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_',
#                                        'suffix': '.png'},
#                               'id': 13165,
#                               'name': 'German Restaurant'}],
#               'chains': [],
#               'distance': 282,
#               'fsq_id': '4dc81f4c315170a4221e250a',
#               'geocodes': {'drop_off': {'latitude': 39.969408,
#                                         'longitude': -75.13443},
#                            'front_door': {'latitude': 39.96944,
#                                           'longitude': -75.134524},
#                            'main': {'latitude': 39.96944,
#                                     'longitude': -75.134524},
#                            'roof': {'latitude': 39.969406,
#                                     'longitude': -75.134724}},
#               'link': '/v3/places/4dc81f4c315170a4221e250a',
#               'location': {'address': '1210 Frankford Ave',
#                            'census_block': '421010144003032',
#                            'country': 'US',
#                            'cross_street': 'btwn W Girard Ave & Thompson St',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1210 Frankford Ave (btwn W '
#                                                 'Girard Ave & Thompson St), '
#                                                 'Philadelphia, PA 19125',
#                            'locality': 'Philadelphia',
#                            'postcode': '19125',
#                            'region': 'PA'},
#               'name': 'Frankford Hall',
#               'related_places': {},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/falafel_',
#                                        'suffix': '.png'},
#                               'id': 13235,
#                               'name': 'Israeli Restaurant'}],
#               'chains': [],
#               'distance': 232,
#               'fsq_id': '5e39fb18c1b6e70008a2cfa7',
#               'geocodes': {'drop_off': {'latitude': 39.970753,
#                                         'longitude': -75.136727},
#                            'main': {'latitude': 39.970677,
#                                     'longitude': -75.136482},
#                            'roof': {'latitude': 39.970677,
#                                     'longitude': -75.136482}},
#               'link': '/v3/places/5e39fb18c1b6e70008a2cfa7',
#               'location': {'address': '1301 N Howard St',
#                            'census_block': '421010144003015',
#                            'country': 'US',
#                            'cross_street': 'at Thompson St',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1301 N Howard St (at Thompson '
#                                                 'St), Philadelphia, PA 19122',
#                            'locality': 'Philadelphia',
#                            'postcode': '19122',
#                            'region': 'PA'},
#               'name': 'Laser Wolf',
#               'related_places': {},
#               'timezone': 'America/New_York'},
#              {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#                                        'suffix': '.png'},
#                               'id': 13314,
#                               'name': 'New American Restaurant'}],
#               'chains': [],
#               'distance': 212,
#               'fsq_id': '5601856e498e1f6975784b0c',
#               'geocodes': {'main': {'latitude': 39.970176,
#                                     'longitude': -75.13559},
#                            'roof': {'latitude': 39.970176,
#                                     'longitude': -75.13559}},
#               'link': '/v3/places/5601856e498e1f6975784b0c',
#               'location': {'address': '1253 N Front St',
#                            'census_block': '421010144003026',
#                            'country': 'US',
#                            'cross_street': '',
#                            'dma': 'Philadelphia',
#                            'formatted_address': '1253 N Front St, '
#                                                 'Philadelphia, PA 19122',
#                            'locality': 'Philadelphia',
#                            'postcode': '19122',
#                            'region': 'PA'},
#               'name': 'Front Street Cafe',
#               'related_places': {'children': []},
#               'timezone': 'America/New_York'}]}

# %%
fsq_df = pd.json_normalize(fsq_res['results'])
print(fsq_df.info())
print(fsq_df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   fsq_id                         10 non-null     object
#  1   categories                     10 non-null     object
#  2   chains                         10 non-null     object
#  3   distance                       10 non-null     int64
#  4   link                           10 non-null     object
#  5   name                           10 non-null     object
#  6   timezone                       10 non-null     object
#  7   geocodes.main.latitude         10 non-null     float64
#  8   geocodes.main.longitude        10 non-null     float64
#  9   geocodes.roof.latitude         10 non-null     float64
#  10  geocodes.roof.longitude        10 non-null     float64
#  11  location.address               10 non-null     object
#  12  location.census_block          10 non-null     object
#  13  location.country               10 non-null     object
#  14  location.cross_street          10 non-null     object
#  15  location.dma                   10 non-null     object
#  16  location.formatted_address     10 non-null     object
#  17  location.locality              10 non-null     object
#  18  location.postcode              10 non-null     object
#  19  location.region                10 non-null     object
#  20  geocodes.drop_off.latitude     7 non-null      float64
#  21  geocodes.drop_off.longitude    7 non-null      float64
#  22  related_places.children        2 non-null      object
#  23  geocodes.front_door.latitude   1 non-null      float64
#  24  geocodes.front_door.longitude  1 non-null      float64
# dtypes: float64(8), int64(1), object(16)
# memory usage: 2.1+ KB
# None
# (10, 25)

# %%
# restaurant testing - Yelp
sort_by = "best_match"

yelp_res = get_yelp(latitude=39.97195, longitude=-75.13445, radius=None, api_key=yelp_key, categories="restaurants")
pprint(yelp_res)
# Out:
# {'businesses': [{'alias': 'suraya-philadelphia-2',
#                  'categories': [{'alias': 'lebanese', 'title': 'Lebanese'},
#                                 {'alias': 'gourmet', 'title': 'Specialty Food'},
#                                 {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#                  'coordinates': {'latitude': 39.9736865005167,
#                                  'longitude': -75.1339557766914},
#                  'display_phone': '(215) 302-1900',
#                  'distance': 197.629294418328,
#                  'id': 'vUrTGX_7HxqeoQ_6QCVz6g',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/H6vumhULeuBQESdnGKxq0w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1528 Frankford Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1528 Frankford Ave',
#                                                   'Philadelphia, PA 19125'],
#                               'state': 'PA',
#                               'zip_code': '19125'},
#                  'name': 'Suraya',
#                  'phone': '+12153021900',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 1415,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/suraya-philadelphia-2?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'pizzeria-beddia-philadelphia',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'bars', 'title': 'Bars'}],
#                  'coordinates': {'latitude': 39.970799,
#                                  'longitude': -75.1349894329906},
#                  'display_phone': '(267) 928-2256',
#                  'distance': 135.99005787602837,
#                  'id': 'uJZgom8HpK74xz8IojpT0A',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CltlyNX3EqDr6zLjEhuzPQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1313 North Lee St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1313 North Lee St',
#                                                   'Philadelphia, PA 19122'],
#                               'state': 'PA',
#                               'zip_code': '19122'},
#                  'name': 'Pizzeria Beddia',
#                  'phone': '+12679282256',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 712,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/pizzeria-beddia-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'wm-mulherins-sons-philadelphia',
#                  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'tapasmallplates',
#                                  'title': 'Tapas/Small Plates'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 39.9717102050781,
#                                  'longitude': -75.1350631713867},
#                  'display_phone': '(215) 291-1355',
#                  'distance': 57.43965830052016,
#                  'id': 'hUmHwBQtGg0iH-PZakQJDw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/22EU-226paz64fA_pGsfoA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1355 N Front St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1355 N Front St',
#                                                   'Philadelphia, PA 19122'],
#                               'state': 'PA',
#                               'zip_code': '19122'},
#                  'name': "Wm Mulherin's Sons",
#                  'phone': '+12152911355',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 709,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/wm-mulherins-sons-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'laser-wolf-philadelphia-2',
#                  'categories': [{'alias': 'mideastern',
#                                  'title': 'Middle Eastern'}],
#                  'coordinates': {'latitude': 39.97049, 'longitude': -75.13662},
#                  'display_phone': '',
#                  'distance': 230.94680226056033,
#                  'id': 'u0Bt7uvvj7LAjAdiMtrhug',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rGW-4FQCEuqcxjzm2VrWdw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1301 N Howard St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1301 N Howard St',
#                                                   'Philadelphia, PA 19122'],
#                               'state': 'PA',
#                               'zip_code': '19122'},
#                  'name': 'Laser Wolf',
#                  'phone': '',
#                  'price': '$$$$',
#                  'rating': 4.5,
#                  'review_count': 365,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/laser-wolf-philadelphia-2?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'cheu-fishtown-philadelphia',
#                  'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 39.9722034535177,
#                                  'longitude': -75.1346028596163},
#                  'display_phone': '(267) 758-2269',
#                  'distance': 31.04738667043342,
#                  'id': 'TjwWB-ET-qmO2-8bfIHMig',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/i_tXvE1JamtH8kef_oPq-g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1416 Frankford Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1416 Frankford Ave',
#                                                   'Philadelphia, PA 19125'],
#                               'state': 'PA',
#                               'zip_code': '19125'},
#                  'name': 'Cheu Fishtown',
#                  'phone': '+12677582269',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 310,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/cheu-fishtown-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'kalaya-philadelphia-7',
#                  'categories': [{'alias': 'thai', 'title': 'Thai'}],
#                  'coordinates': {'latitude': 39.97551, 'longitude': -75.133},
#                  'display_phone': '(215) 545-2535',
#                  'distance': 427.3472741437602,
#                  'id': 'HbnWgfnaX-kUobTx2QTWpQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GXfcrfTduPzBWwZ38GCmBQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4 W Palmer St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['4 W Palmer St',
#                                                   'Philadelphia, PA 19125'],
#                               'state': 'PA',
#                               'zip_code': '19125'},
#                  'name': 'Kalaya',
#                  'phone': '+12155452535',
#                  'rating': 4.0,
#                  'review_count': 199,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kalaya-philadelphia-7?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'lmno-philadelphia',
#                  'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#                  'coordinates': {'latitude': 39.97604, 'longitude': -75.13377},
#                  'display_phone': '(215) 770-7001',
#                  'distance': 464.8792032936967,
#                  'id': 'zvvl3c1FO3O3BZdhusficA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/i5R9RiZbhTRqN0bwfGzG0A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1739-49 N Front St',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1739-49 N Front St',
#                                                   'Philadelphia, PA 19122'],
#                               'state': 'PA',
#                               'zip_code': '19122'},
#                  'name': 'LMNO',
#                  'phone': '+12157707001',
#                  'rating': 4.0,
#                  'review_count': 203,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/lmno-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'middle-child-clubhouse-philadelphia',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'}],
#                  'coordinates': {'latitude': 39.96997803501411,
#                                  'longitude': -75.13599882054913},
#                  'display_phone': '',
#                  'distance': 255.93032007321415,
#                  'id': 'ORmx8v2fWefT1Ka54Up0MQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/TgMSVqc2UwQkxdm2Td3Bcw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1232 N Front St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1232 N Front St',
#                                                   'Philadelphia, PA 19122'],
#                               'state': 'PA',
#                               'zip_code': '19122'},
#                  'name': 'Middle Child Clubhouse',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 136,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/middle-child-clubhouse-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'urban-village-brewing-co-philadelphia',
#                  'categories': [{'alias': 'breweries', 'title': 'Breweries'},
#                                 {'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'newamerican',
#                                  'title': 'American (New)'}],
#                  'coordinates': {'latitude': 39.9667, 'longitude': -75.13997},
#                  'display_phone': '(267) 687-1961',
#                  'distance': 749.7146534682142,
#                  'id': '2SYEGA2fZLdzZQ9lmIfM5Q',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ezj1mK__Jptkoqi_WAj_NA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1001 N 2nd St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1001 N 2nd St',
#                                                   'Philadelphia, PA 19123'],
#                               'state': 'PA',
#                               'zip_code': '19123'},
#                  'name': 'Urban Village Brewing Co',
#                  'phone': '+12676871961',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 273,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/urban-village-brewing-co-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'love-and-honey-fried-chicken-philadelphia-2',
#                  'categories': [{'alias': 'chickenshop',
#                                  'title': 'Chicken Shop'},
#                                 {'alias': 'chicken_wings',
#                                  'title': 'Chicken Wings'},
#                                 {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'coordinates': {'latitude': 39.967461,
#                                  'longitude': -75.136992},
#                  'display_phone': '(215) 789-7878',
#                  'distance': 540.8570744418631,
#                  'id': 'GWqPmrWu0kXB_-gB1H-j6A',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_5aapSJQi9jKHWAebvzu_g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1100 N Front St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1100 N Front St',
#                                                   'Philadelphia, PA 19123'],
#                               'state': 'PA',
#                               'zip_code': '19123'},
#                  'name': 'Love & Honey Fried Chicken',
#                  'phone': '+12157897878',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 469,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/love-and-honey-fried-chicken-philadelphia-2?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'apricot-stone-philadelphia-4',
#                  'categories': [{'alias': 'mediterranean',
#                                  'title': 'Mediterranean'},
#                                 {'alias': 'mideastern',
#                                  'title': 'Middle Eastern'},
#                                 {'alias': 'armenian', 'title': 'Armenian'}],
#                  'coordinates': {'latitude': 39.967331590792,
#                                  'longitude': -75.1404441920654},
#                  'display_phone': '(267) 606-6596',
#                  'distance': 724.3318515105676,
#                  'id': 'cbr2Db20L6P50CsxsX6c2A',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eMUgSPMfN4XV1C68J55zSQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1040 N American St',
#                               'address2': 'Ste 601',
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1040 N American St',
#                                                   'Ste 601',
#                                                   'Philadelphia, PA 19123'],
#                               'state': 'PA',
#                               'zip_code': '19123'},
#                  'name': 'Apricot Stone',
#                  'phone': '+12676066596',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 351,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/apricot-stone-philadelphia-4?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'front-street-cafe-philadelphia',
#                  'categories': [{'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'}],
#                  'coordinates': {'latitude': 39.9696302826962,
#                                  'longitude': -75.1359319409314},
#                  'display_phone': '(215) 515-3073',
#                  'distance': 219.13580361233093,
#                  'id': 'JrG4NINLspXPNhSXg7Q07Q',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tSFHaWodxsHorwjRP72HOw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1253 N Front St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1253 N Front St',
#                                                   'Philadelphia, PA 19122'],
#                               'state': 'PA',
#                               'zip_code': '19122'},
#                  'name': 'Front Street Cafe',
#                  'phone': '+12155153073',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 823,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/front-street-cafe-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'lloyd-whiskey-bar-philadelphia-2',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'cocktailbars',
#                                  'title': 'Cocktail Bars'},
#                                 {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#                  'coordinates': {'latitude': 39.971357533145,
#                                  'longitude': -75.127588676978},
#                  'display_phone': '(215) 425-4600',
#                  'distance': 588.3908714510414,
#                  'id': 'DytKODMqcvQ7MWA0NN2uNw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nvQBkS3YuPa4NCnIZnd0fw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '529 E Girard Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['529 E Girard Ave',
#                                                   'Philadelphia, PA 19125'],
#                               'state': 'PA',
#                               'zip_code': '19125'},
#                  'name': 'Lloyd Whiskey Bar',
#                  'phone': '+12154254600',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 221,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/lloyd-whiskey-bar-philadelphia-2?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'suttons-philadelphia',
#                  'categories': [{'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'}],
#                  'coordinates': {'latitude': 39.9771594075637,
#                                  'longitude': -75.1436727494001},
#                  'display_phone': '(267) 534-4151',
#                  'distance': 976.2996054218557,
#                  'id': 'hxPnlWZmirx7neooZykmtg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rwV13gjf5iUWzvKeCT9b7w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1706 N 5th St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1706 N 5th St',
#                                                   'Philadelphia, PA 19122'],
#                               'state': 'PA',
#                               'zip_code': '19122'},
#                  'name': "Sutton's",
#                  'phone': '+12675344151',
#                  'price': '$$',
#                  'rating': 5.0,
#                  'review_count': 87,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/suttons-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'heritage-philadelphia',
#                  'categories': [{'alias': 'newamerican',
#                                  'title': 'American (New)'},
#                                 {'alias': 'jazzandblues',
#                                  'title': 'Jazz & Blues'}],
#                  'coordinates': {'latitude': 39.96467, 'longitude': -75.14086},
#                  'display_phone': '(215) 627-7500',
#                  'distance': 982.0648982935571,
#                  'id': '5AGVyIa1_XVUqXGbQXRmiQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZPxAZJJWL8QiuvjMZaJb3A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '914 N 2nd St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['914 N 2nd St',
#                                                   'Philadelphia, PA 19123'],
#                               'state': 'PA',
#                               'zip_code': '19123'},
#                  'name': 'Heritage',
#                  'phone': '+12156277500',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 326,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/heritage-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'hiroki-philadelphia',
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#                  'coordinates': {'latitude': 39.9711593,
#                                  'longitude': -75.1353356},
#                  'display_phone': '',
#                  'distance': 107.7500068491048,
#                  'id': '9ANZAxxwp-UAxqUo3KF9gg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vgOhZVO95xOxljl0meFddg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1335 N Front St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1335 N Front St',
#                                                   'Philadelphia, PA 19122'],
#                               'state': 'PA',
#                               'zip_code': '19122'},
#                  'name': 'Hiroki',
#                  'phone': '',
#                  'price': '$$$$',
#                  'rating': 4.0,
#                  'review_count': 160,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/hiroki-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'cafe-la-maude-philadelphia',
#                  'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#                                 {'alias': 'breakfast_brunch',
#                                  'title': 'Breakfast & Brunch'},
#                                 {'alias': 'mediterranean',
#                                  'title': 'Mediterranean'}],
#                  'coordinates': {'latitude': 39.963948,
#                                  'longitude': -75.144364},
#                  'display_phone': '(267) 318-7869',
#                  'distance': 1226.9960161071547,
#                  'id': 'K7KHmHzxNwzqiijSJeKe_A',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cPQpTg-zjqdoT7NbUSHybg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '816 N 4th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['816 N 4th St',
#                                                   'Philadelphia, PA 19123'],
#                               'state': 'PA',
#                               'zip_code': '19123'},
#                  'name': 'Cafe La Maude',
#                  'phone': '+12673187869',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1766,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/cafe-la-maude-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'johnny-brendas-philadelphia',
#                  'categories': [{'alias': 'bars', 'title': 'Bars'},
#                                 {'alias': 'burgers', 'title': 'Burgers'},
#                                 {'alias': 'musicvenues',
#                                  'title': 'Music Venues'}],
#                  'coordinates': {'latitude': 39.9691429138184,
#                                  'longitude': -75.134162902832},
#                  'display_phone': '(215) 739-9684',
#                  'distance': 318.15912234290107,
#                  'id': '6x9hcZ1CJ4S9avBgPGS7-Q',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/miOcxc_OCDpr1ZGT2Gyu_Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1201 Frankford Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1201 Frankford Ave',
#                                                   'Philadelphia, PA 19125'],
#                               'state': 'PA',
#                               'zip_code': '19125'},
#                  'name': "Johnny Brenda's",
#                  'phone': '+12157399684',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 595,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/johnny-brendas-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'interstate-drafthouse-philadelphia',
#                  'categories': [{'alias': 'southern', 'title': 'Southern'},
#                                 {'alias': 'divebars', 'title': 'Dive Bars'},
#                                 {'alias': 'tradamerican',
#                                  'title': 'American (Traditional)'}],
#                  'coordinates': {'latitude': 39.97199, 'longitude': -75.128871},
#                  'display_phone': '(267) 455-0045',
#                  'distance': 475.4359459547937,
#                  'id': '_n539Sga7PCvHQs--a4qkA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uyna8-ggfyNwe2ZioqbLJA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1235 E Palmer St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['1235 E Palmer St',
#                                                   'Philadelphia, PA 19125'],
#                               'state': 'PA',
#                               'zip_code': '19125'},
#                  'name': 'Interstate Drafthouse',
#                  'phone': '+12674550045',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 264,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/interstate-drafthouse-philadelphia?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'},
#                 {'alias': 'chubby-cattle-philadelphia-5',
#                  'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#                                 {'alias': 'hotpot', 'title': 'Hot Pot'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'coordinates': {'latitude': 39.95498, 'longitude': -75.15622},
#                  'display_phone': '(866) 622-8853',
#                  'distance': 2638.7923234340915,
#                  'id': 'iksVwRfpWymIUUFqw0tXpw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gFMPEENrXHR6KC9iTmiPqA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '146 N 10th St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Philadelphia',
#                               'country': 'US',
#                               'display_address': ['146 N 10th St',
#                                                   'Philadelphia, PA 19107'],
#                               'state': 'PA',
#                               'zip_code': '19107'},
#                  'name': 'Chubby Cattle',
#                  'phone': '+18666228853',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1483,
#                  'transactions': ['delivery',
#                                   'pickup',
#                                   'restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/chubby-cattle-philadelphia-5?adjust_creative=qkVw-EvQl0ErtaCtwso2bQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=qkVw-EvQl0ErtaCtwso2bQ'}],
#  'region': {'center': {'latitude': 39.97195, 'longitude': -75.13445}},
#  'total': 4000}

# %%
yelp_df = pd.json_normalize(yelp_res['businesses'])
print(yelp_df.info())
print(yelp_df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        20 non-null     object
#  1   alias                     20 non-null     object
#  2   name                      20 non-null     object
#  3   image_url                 20 non-null     object
#  4   is_closed                 20 non-null     bool
#  5   url                       20 non-null     object
#  6   review_count              20 non-null     int64
#  7   categories                20 non-null     object
#  8   rating                    20 non-null     float64
#  9   transactions              20 non-null     object
#  10  price                     18 non-null     object
#  11  phone                     20 non-null     object
#  12  display_phone             20 non-null     object
#  13  distance                  20 non-null     float64
#  14  coordinates.latitude      20 non-null     float64
#  15  coordinates.longitude     20 non-null     float64
#  16  location.address1         20 non-null     object
#  17  location.address2         13 non-null     object
#  18  location.address3         13 non-null     object
#  19  location.city             20 non-null     object
#  20  location.zip_code         20 non-null     object
#  21  location.country          20 non-null     object
#  22  location.state            20 non-null     object
#  23  location.display_address  20 non-null     object
# dtypes: bool(1), float64(4), int64(1), object(18)
# memory usage: 3.7+ KB
# None
# (20, 24)

# %% [markdown]
# #### *The Yelp API has more information especially with regards to ratings, reviews, price etc.* I worked with fitness and college POIs, not restaurants, but a comparison of dataframe snippets are below.

# %% [markdown]
# The Yelp API gives 20 businesses for the first lat-lng pair while the Foursquare API yields 10; the Foursquare API gives more information on the location while the Yelp API gives more business-focused details.

# %%
yelp_df.head()
# Out:
#                        id                           alias                name  \
# 0  vUrTGX_7HxqeoQ_6QCVz6g           suraya-philadelphia-2              Suraya
# 1  uJZgom8HpK74xz8IojpT0A    pizzeria-beddia-philadelphia     Pizzeria Beddia
# 2  hUmHwBQtGg0iH-PZakQJDw  wm-mulherins-sons-philadelphia  Wm Mulherin's Sons
# 3  u0Bt7uvvj7LAjAdiMtrhug       laser-wolf-philadelphia-2          Laser Wolf
# 4  TjwWB-ET-qmO2-8bfIHMig      cheu-fishtown-philadelphia       Cheu Fishtown
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/H6vumh...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/CltlyN...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/22EU-2...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/rGW-4F...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/i_tXvE...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/suraya-philadelphia-2...          1415
# 1  https://www.yelp.com/biz/pizzeria-beddia-phila...           712
# 2  https://www.yelp.com/biz/wm-mulherins-sons-phi...           709
# 3  https://www.yelp.com/biz/laser-wolf-philadelph...           365
# 4  https://www.yelp.com/biz/cheu-fishtown-philade...           310
#
#                                           categories  rating  \
# 0  [{'alias': 'lebanese', 'title': 'Lebanese'}, {...     4.5
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 2  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 3  [{'alias': 'mideastern', 'title': 'Middle East...     4.5
# 4  [{'alias': 'noodles', 'title': 'Noodles'}, {'a...     4.0
#
#          transactions  ... coordinates.latitude coordinates.longitude  \
# 0          [delivery]  ...            39.973687            -75.133956
# 1          [delivery]  ...            39.970799            -75.134989
# 2          [delivery]  ...            39.971710            -75.135063
# 3          [delivery]  ...            39.970490            -75.136620
# 4  [delivery, pickup]  ...            39.972203            -75.134603
#
#     location.address1  location.address2  location.address3  location.city  \
# 0  1528 Frankford Ave                                  None   Philadelphia
# 1   1313 North Lee St                                         Philadelphia
# 2     1355 N Front St               None                      Philadelphia
# 3    1301 N Howard St               None                      Philadelphia
# 4  1416 Frankford Ave                                  None   Philadelphia
#
#   location.zip_code location.country location.state  \
# 0             19125               US             PA
# 1             19122               US             PA
# 2             19122               US             PA
# 3             19122               US             PA
# 4             19125               US             PA
#
#                        location.display_address
# 0  [1528 Frankford Ave, Philadelphia, PA 19125]
# 1   [1313 North Lee St, Philadelphia, PA 19122]
# 2     [1355 N Front St, Philadelphia, PA 19122]
# 3    [1301 N Howard St, Philadelphia, PA 19122]
# 4  [1416 Frankford Ave, Philadelphia, PA 19125]
#
# [5 rows x 24 columns]

# %%
fsq_df.head()
# Out:
#                      fsq_id  \
# 0  56fb2e82498ec4440b0aa2e9
# 1  5427166a498e85a2c0b936b3
# 2  5c958f5e2619ee002c1a8470
# 3  507ad324e4b0c101c709028d
# 4  597397c3851de565cc92bc6d
#
#                                           categories chains  distance  \
# 0  [{'id': 13009, 'name': 'Cocktail Bar', 'icon':...     []        59
# 1  [{'id': 13034, 'name': 'Café', 'icon': {'prefi...     []        83
# 2  [{'id': 13064, 'name': 'Pizzeria', 'icon': {'p...     []       155
# 3  [{'id': 13022, 'name': 'Sports Bar', 'icon': {...     []       159
# 4  [{'id': 13263, 'name': 'Japanese Restaurant', ...     []        38
#
#                                   link                        name  \
# 0  /v3/places/56fb2e82498ec4440b0aa2e9         Wm. Mulherin's Sons
# 1  /v3/places/5427166a498e85a2c0b936b3  La Colombe Coffee Roasters
# 2  /v3/places/5c958f5e2619ee002c1a8470             Pizzeria Beddia
# 3  /v3/places/507ad324e4b0c101c709028d             Bottle Bar East
# 4  /v3/places/597397c3851de565cc92bc6d               Cheu Fishtown
#
#            timezone  geocodes.main.latitude  geocodes.main.longitude  \
# 0  America/New_York               39.971695               -75.134998
# 1  America/New_York               39.971136               -75.134231
# 2  America/New_York               39.970664               -75.135406
# 3  America/New_York               39.970528               -75.134752
# 4  America/New_York               39.972245               -75.134603
#
#    geocodes.roof.latitude  ...  location.dma  \
# 0               39.971695  ...  Philadelphia
# 1               39.971136  ...  Philadelphia
# 2               39.970664  ...  Philadelphia
# 3               39.970528  ...  Philadelphia
# 4               39.972245  ...  Philadelphia
#
#                           location.formatted_address location.locality  \
# 0            1355 N Front St, Philadelphia, PA 19122      Philadelphia
# 1  1335 Frankford Ave (btwn Mercer & Master St), ...      Philadelphia
# 2  1313 N LEE St (btwn Master & Thompson St), Phi...      Philadelphia
# 3  1308 Frankford Ave (at Thompson St), Philadelp...      Philadelphia
# 4         1416 Frankford Ave, Philadelphia, PA 19125      Philadelphia
#
#   location.postcode location.region geocodes.drop_off.latitude  \
# 0             19122              PA                        NaN
# 1             19125              PA                  39.971139
# 2             19125              PA                        NaN
# 3             19125              PA                  39.970518
# 4             19125              PA                  39.972243
#
#   geocodes.drop_off.longitude related_places.children  \
# 0                         NaN                     NaN
# 1                  -75.134416                     NaN
# 2                         NaN                     NaN
# 3                  -75.134431                     NaN
# 4                  -75.134402                     NaN
#
#   geocodes.front_door.latitude geocodes.front_door.longitude
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
# [5 rows x 25 columns]
